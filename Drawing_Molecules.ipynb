# %% [markdown]
# # Drawing molecules in iPython Notebook

# %%
from __future__ import print_function
import oddt

# %%
print(oddt.__version__)
# Out:
# 0.4.1-15-gf7f6653

# %% [markdown]
# ### 1. Download molecule from PDBbind

# %%
# %%bash
# wget -q -N www.pdbbind.org.cn/v2007/10gs/10gs_ligand.mol2

# %% [markdown]
# ### 2. Variables controling images
#
# There are two main variables for controling the drawing, namely `image_size` and `image_backend` located in a `oddt.toolkit` namespace. There are two backends available PNG (default) and SVG.

# %%
print('Default size: ', oddt.toolkit.image_size)
print('Default backend: ', oddt.toolkit.image_backend)
# Out:
# Default size:  (200, 200)
# Default backend:  png

# %% [markdown]
# ### 3. OpenBabel Drawing
# OpenBabel is the default toolkit, although just for assurance will asign is as the toolkit of choice.

# %%
oddt.toolkit = oddt.toolkits.ob
mol = next(oddt.toolkit.readfile('mol2', '10gs_ligand.mol2'))
mol.removeh()

# %% [markdown]
# #### 3.1 OB PNG (default)

# %%
mol
# Out:
# <img src="data:image/png;base64,..." alt="10gs_ligand">

# %% [markdown]
# #### 3.2 OB SVG

# %%
oddt.toolkit.image_backend = 'svg'
mol
# Out:
# <?xml version="1.0"?><svg version="1.1" id="topsvg"xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"xmlns:cml="http://www.xml-cml.org/schema" x="0" y="0" width="200px" height="200px" viewBox="0 0 100 100"><title>10gs_ligand - Open Babel Depiction</title><rect x="0" y="0" width="100" height="100" fill="white"/><g transform="translate(0,0)"><svg width="100" height="100" x="0" y="0" viewBox="0 0 391.769 460"font-family="sans-serif" stroke="rgb(0,0,0)" stroke-width="4"  stroke-linecap="round"><polygon points="317.128 100 342.338 109.936 338.338 116.864 " stroke-width="4" fill="rgb(0,0,0)"  stroke="rgb(0,0,0)" /><line x1="317.1" y1="100.0" x2="282.5" y2="120.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="317.1" y1="100.0" x2="317.1" y2="60.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="315.6" y1="57.4" x2="339.0" y2="43.9" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="318.6" y1="62.6" x2="342.0" y2="49.1" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="317.1" y1="60.0" x2="293.7" y2="46.5" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="282.5" y1="120.0" x2="282.5" y2="160.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="282.5" y1="160.0" x2="247.8" y2="180.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="246.3" y1="182.6" x2="223.0" y2="169.1" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="249.3" y1="177.4" x2="226.0" y2="163.9" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="247.8" y1="180.0" x2="247.8" y2="207.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="236.6" y1="226.5" x2="213.2" y2="240.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="205.9" y1="236.7" x2="206.7" y2="235.3" stroke="rgb(0,0,0)"  stroke-width="1.0"/><line x1="200.0" y1="234.0" x2="201.5" y2="231.6" stroke="rgb(0,0,0)"  stroke-width="1.0"/><line x1="194.2" y1="231.4" x2="196.2" y2="227.8" stroke="rgb(0,0,0)"  stroke-width="1.0"/><line x1="188.3" y1="228.8" x2="191.0" y2="224.0" stroke="rgb(0,0,0)"  stroke-width="1.0"/><line x1="182.4" y1="226.1" x2="185.8" y2="220.3" stroke="rgb(0,0,0)"  stroke-width="1.0"/><line x1="176.6" y1="223.5" x2="180.6" y2="216.5" stroke="rgb(0,0,0)"  stroke-width="1.0"/><line x1="213.2" y1="240.0" x2="213.2" y2="280.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="178.6" y1="220.0" x2="155.2" y2="233.5" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="143.9" y1="253.0" x2="143.9" y2="280.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="143.9" y1="280.0" x2="109.3" y2="300.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="214.7" y1="282.6" x2="191.3" y2="296.1" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="211.7" y1="277.4" x2="188.3" y2="290.9" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="213.2" y1="280.0" x2="236.6" y2="293.5" stroke="rgb(0,0,0)"  stroke-width="4.0"/><polygon points="247.846097 340.000000 243.846097 313.200000 251.846097 313.200000 " stroke-width="4.000000" fill="rgb(0,0,0)"  stroke="rgb(0,0,0)" /><line x1="247.8" y1="340.0" x2="213.2" y2="360.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="247.8" y1="340.0" x2="282.5" y2="360.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="285.5" y1="360.0" x2="285.5" y2="387.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="279.5" y1="360.0" x2="279.5" y2="387.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="282.5" y1="360.0" x2="305.9" y2="346.5" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="109.3" y1="340.0" x2="109.3" y2="300.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="102.1" y1="334.0" x2="102.1" y2="306.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="109.3" y1="300.0" x2="74.6" y2="280.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="74.6" y1="280.0" x2="40.0" y2="300.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="73.0" y1="289.2" x2="48.8" y2="303.2" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="40.0" y1="300.0" x2="40.0" y2="340.0" stroke="rgb(0,0,0)"  stroke-width="4.0"/><line x1="40.0" y1="340.0" x2="74.6" ...

# %% [markdown]
# ### 4. RDKit molecules are drawn in the same way

# %%
oddt.toolkit = oddt.toolkits.rdk
mol = next(oddt.toolkit.readfile('mol2', '10gs_ligand.mol2'))
mol.removeh()

# %% [markdown]
# #### 4.1 RDKit PNG

# %%
oddt.toolkit.image_backend = 'png'
mol
# Out:
# <img src="data:image/png;base64,..." alt="10gs_ligand">

# %% [markdown]
# #### 4.2 RDKit SVG

# %%
oddt.toolkit.image_backend = 'svg'
mol
# Out:
# <?xml version='1.0' encoding='iso-8859-1'?><svg version='1.1' baseProfile='full'              xmlns:svg='http://www.w3.org/2000/svg'                      xmlns:rdkit='http://www.rdkit.org/xml'                      xmlns:xlink='http://www.w3.org/1999/xlink'                  xml:space='preserve'width='200px' height='200px' ><rect style='opacity:1.0;fill:#FFFFFF;stroke:none' width='200' height='200' x='0' y='0'> </rect><path d='M 71.1273,50.9488 66.5066,54.5236' style='fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 66.5066,54.5236 61.8858,58.0985' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 61.8858,58.0985 64.2291,75.3684' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 61.8858,58.0985 45.7579,51.4929' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 45.7579,51.4929 44.803,44.4555' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 44.803,44.4555 43.8481,37.4181' style='fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 44.6914,50.1144 39.1556,54.3972' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 39.1556,54.3972 33.6198,58.68' style='fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 46.8243,52.8713 41.2885,57.1541' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 41.2885,57.1541 35.7527,61.4369' style='fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 64.2291,75.3684 80.3571,81.974' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 80.3571,81.974 82.7004,99.244' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 81.634,97.8655 76.0982,102.148' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 76.0982,102.148 70.5623,106.431' style='fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 83.7669,100.622 78.231,104.905' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 78.231,104.905 72.6952,109.188' style='fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 82.7004,99.244 88.2467,101.516' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 88.2467,101.516 93.793,103.787' style='fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 99.2225,108.754 100.197,115.937' style='fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 100.197,115.937 101.172,123.12' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1' /><path d='M 101.172,123.12 117.3,129.725' style='fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;strok ...

# %% [markdown]
# ### 5. Changing a size of a molecule
# A size can be arbitrally set to an int or two element tuple/list. It is a global setting appplied in all subsequent images.

# %%
oddt.toolkit.image_backend = 'png'
oddt.toolkit.image_size = 100

# %%
mol
# Out:
# <img src="data:image/png;base64,..." alt="10gs_ligand">

# %%
oddt.toolkit.image_size = (600, 400)

# %%
mol
# Out:
# <img src="data:image/png;base64,..." alt="10gs_ligand">
